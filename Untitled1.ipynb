# %%
import pandas as pd
import numpy as np

# %%
 dates = pd.date_range('04/21/1998', periods=60)

# %%
dates
# Out:
# DatetimeIndex(['1998-04-21', '1998-04-22', '1998-04-23', '1998-04-24',
#                '1998-04-25', '1998-04-26', '1998-04-27', '1998-04-28',
#                '1998-04-29', '1998-04-30', '1998-05-01', '1998-05-02',
#                '1998-05-03', '1998-05-04', '1998-05-05', '1998-05-06',
#                '1998-05-07', '1998-05-08', '1998-05-09', '1998-05-10',
#                '1998-05-11', '1998-05-12', '1998-05-13', '1998-05-14',
#                '1998-05-15', '1998-05-16', '1998-05-17', '1998-05-18',
#                '1998-05-19', '1998-05-20', '1998-05-21', '1998-05-22',
#                '1998-05-23', '1998-05-24', '1998-05-25', '1998-05-26',
#                '1998-05-27', '1998-05-28', '1998-05-29', '1998-05-30',
#                '1998-05-31', '1998-06-01', '1998-06-02', '1998-06-03',
#                '1998-06-04', '1998-06-05', '1998-06-06', '1998-06-07',
#                '1998-06-08', '1998-06-09', '1998-06-10', '1998-06-11',
# ...

# %%
days = ['Tuesday', 'Wednesday', 'Thursday', 'Fryday', 'Satarday', 'Sunday', 'Monday']

# %%
df = pd.DataFrame(np.random.randn(60, 7),
                  index=dates, columns=days)

# %%
df
# Out:
#              Tuesday  Wednesday  Thursday    Fryday  Satarday    Sunday  \
# 1998-04-21 -1.218718  -0.989900  1.503660 -1.088428  1.796698 -0.469451
# 1998-04-22 -1.068189  -0.526589  2.011010 -0.105759  0.628554  0.517684
# 1998-04-23  0.590304   0.404474 -0.110343 -0.882249 -1.416360  1.099698
# 1998-04-24 -1.706129  -0.838678 -2.327196 -0.711141 -2.023717  1.172600
# 1998-04-25  0.435384   0.317387  0.019159 -1.205599 -0.536107 -1.231361
# 1998-04-26 -1.361520   0.730335 -0.604634 -0.382967  0.316781  0.197099
# 1998-04-27  0.534257  -1.650538  0.213111 -0.501389  0.984225  0.303009
# 1998-04-28  0.290905   0.644293 -0.607448  1.990936 -0.410099  2.487516
# 1998-04-29  0.731614   1.119791 -1.343691 -1.023932  1.137830  2.861802
# 1998-04-30 -0.776740  -0.742576 -1.137450 -0.163133 -0.182702  0.711902
# 1998-05-01 -1.355999  -0.853702 -0.383523  0.614336 -1.503410 -0.567608
# 1998-05-02 -1.002861  -1.009842  1.127521 -2.238365  0.562768  0.604050
# ...

# %%
s = pd.Series
